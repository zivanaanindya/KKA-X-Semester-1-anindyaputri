# %% [markdown]
# <a href="https://colab.research.google.com/github/zivanaanindya/KKA-X-Semester-1-anindyaputri/blob/main/2_tipe_variabel_anindyarp_x_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Nama : Zivana Anindya

Kelas:X-2

absen:36

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("zivanaanindya9810@gmail.com")
print("zivanaanindya8910@gmail.com")
print("zivanaanindya8910@gmail.com")
# Out:
# zivanaanindya9810@gmail.com
# zivanaanindya8910@gmail.com
# zivanaanindya8910@gmail.com

# %%
email_user = "zivanaanindya8910@gmail.com"

print(email_user)
print(email_user)
print(email_user)
# Out:
# zivanaanindya8910@gmail.com
# zivanaanindya8910@gmail.com
# zivanaanindya8910@gmail.com

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
#hanya boleh menggunakan angka,huruf,dan underscore
harga telur = 15000
print(harga telur)
# Out:
#   File "/tmp/ipython-input-2175948713.py", line 2
#     harga telur = 15000
#           ^
# SyntaxError: invalid syntax

# %%
hargatelur = 15000
print(hargatelur)
# Out:
# 15000

# %%
#tidak boleh diawali dengan angka
1_nama_siswa = "ahmad dani"
print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-344366506.py", line 2
#     1_nama_siswa = "ahmad dani"
#      ^
# SyntaxError: invalid decimal literal

# %%
#tidak boleh menggunakan kata kunci phyton
if = "handayani"
print (if)
# Out:
#   File "/tmp/ipython-input-2560381170.py", line 2
#     if = "handayani"
#        ^
# SyntaxError: invalid syntax

# %%
IF = "handayani"
print(IF)
# Out:
# handayani

# %%
print = "noor"
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-178869753.py in <cell line: 0>()
#       1 print = "noor"
# ----> 2 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "noor"
print(Print)
# Out:
# noor

# %%
#sensitif terhadap penulisan kapital
USIA = 17
print(Usia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3015126514.py in <cell line: 0>()
#       1 #sensitif terhadap penulisan kapital
#       2 USIA = 17
# ----> 3 print(Usia)
#
# NameError: name 'Usia' is not defined

# %%
print(USIA)
# Out:
# 17

# %%
_ = "fazel wardana"

# %%
_ = "lia wati"

# %%
print(_)
# Out:
# lia wati

# %% [markdown]
# #assignment

# %%
#single assignment
bb_fazel = 55
bb_dani = 60

print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
#multiple assigment
bb_fazel, bb_dani = 55,60
print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
bb_fazel,bb_dani = 50,60,70
print(bb_dani)
print(bb_fazel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1224797316.py in <cell line: 0>()
# ----> 1 bb_fazel,bb_dani = 50,60,70
#       2 print(bb_dani)
#       3 print(bb_fazel)
#
# ValueError: too many values to unpack (expected 2)

# %%
nama_siswa_1,nama_siswa_2 = "deni","doni"
print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# deni
# doni

# %%
bb_fazel,bb_dani,bb_adli=50,60
print(bb_dani)
print(bb_fazel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3760375824.py in <cell line: 0>()
# ----> 1 bb_fazel,bb_dani,bb_adli=50,60
#       2 print(bb_dani)
#       3 print(bb_fazel)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
#chain assignment
bb_hasbi = bb_dani = 50
print(bb_hasbi)
print(bb_dani)
# Out:
# 50
# 50

# %% [markdown]
# #cara penulisan operator pada python

# %%
#tanpa variabel
print(9+6)
# Out:
# 15

# %%
print("shinta")
# Out:
# shinta

# %%
print("9+6")
# Out:
# 9+6

# %%
#operand di simpan di variabel
jumlah_hp_habibi =10
jumlah_hp_syauqi =6
print(jumlah_hp_habibi + jumlah_hp_syauqi)
# Out:
# 16

# %%
#hasil operasi disimpan divariabel
total_hp = 10 + 6
print(total_hp)
# Out:
# 16

# %%
#operand dan hasil operasi disimpan divariabel
jumlah_hp_habibi = 10
jumlah_hp_syauqi = 6
total_hp = jumlah_hp_habibi + jumlah_hp_syauqi
print(total_hp)
# Out:
# 16

# %% [markdown]
# #soal latihan coding(assignment)

# %%
#single assignment
nama = "andi"
print(nama)
# Out:
# andi

# %%
#multiple assignment
nama = "budi"
umur = 15
kelas = "9A"
print(nama,umur,kelas)
# Out:
# budi 15 9A

# %%
#chain assignment
berat_andi = berat_siti = berat_eko = 45.5
print(berat_andi,berat_siti,berat_eko)
# Out:
# 45.5 45.5 45.5

# %% [markdown]
# #soal

# %%
print(24*3)
# Out:
# 72

# %%
total_jumlah_botol=24*3
print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus=24
jumlah_kardus=3

print(banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus=24
jumlah_kardus=3
total_jumlah_botol=banyak_botol_per_kardus*jumlah_kardus
print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Operator perbandingan

# %%
print(6>=6)
# Out:
# True

# %%
print(8==9)
# Out:
# False

# %%
print(8!=9)
# Out:
# True

# %%
print(8<10)
# Out:
# True

# %%
print(8>10)
# Out:
# False

# %%
print(not(5<=5))
# Out:
# False

# %%
print(8>7 and 6<5)
# Out:
# False

# %%
print(7<=1 or 2!=2)
# Out:
# False

# %%
print(not(0==1 and 1!=1))
# Out:
# True

# %%
print(not(5<10 or 5<=10))
# Out:
# False
